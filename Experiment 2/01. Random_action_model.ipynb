# %% [markdown]
# # Random action agent

# %%
import pprint
from Environment.simulator import *
from Environment.my_utils import *
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv

import warnings
warnings.filterwarnings("ignore")

# %%
SLA = 2.5
VM_TYPE1 = 7
VM_TYPE2 = 3
VM_TYPE3 = 1
PENALTY = 10000
STEPS = 100
ALPHA = 0.75
BETA = 0.25

# %% [markdown]
# Make own copy of the scenarios

# %%
copy_scenario('test_scenario_1', 'random')
copy_scenario('test_scenario_2', 'random')
copy_scenario('test_scenario_3', 'random')
copy_scenario('test_scenario_4', 'random')
copy_scenario('test_scenario_5', 'random')

# %% [markdown]
# Test performce on random actions

# %%
SCENARIO = "Environment/Scenarios/test_scenario_1_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 2.3776093278066144, 'Current cost': 165, 'Queue': [7, 7, 7, 7, 7, 7, 7, 7, 7, 7], 'Timer': 4.205905437469482, 'VM type I': 1, 'VM type II': 2, 'VM type III': 1}
# Cumulative reward at the end of the test:  -195.0
# Avg cost minus penalty per step:  5.11
# Avg quality of service:  2.65
# Avg no of virtual machines:  10.55

# %%
SCENARIO = "Environment/Scenarios/test_scenario_2_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 2.1134430530861037, 'Current cost': 775, 'Queue': [5, 6, 6, 6, 6, 6, 6, 6, 6, 6], 'Timer': 4.7316155433654785, 'VM type I': 10, 'VM type II': 10, 'VM type III': 3}
# Cumulative reward at the end of the test:  -930
# Avg cost minus penalty per step:  11.48
# Avg quality of service:  1.58
# Avg no of virtual machines:  22.95

# %%
SCENARIO = "Environment/Scenarios/test_scenario_3_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 1.565040791469661, 'Current cost': 220, 'Queue': [15, 14, 14, 14, 14, 14, 14, 14, 14, 14], 'Timer': 6.3896098136901855, 'VM type I': 2, 'VM type II': 3, 'VM type III': 1}
# Cumulative reward at the end of the test:  -490.0
# Avg cost minus penalty per step:  6.67
# Avg quality of service:  2.44
# Avg no of virtual machines:  9.04

# %%
SCENARIO = "Environment/Scenarios/test_scenario_4_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 1.4034326464897302, 'Current cost': 190, 'Queue': [16, 17, 17, 17, 17, 17, 17, 17, 17, 17], 'Timer': 7.125386476516724, 'VM type I': 4, 'VM type II': 1, 'VM type III': 1}
# Cumulative reward at the end of the test:  -850.0
# Avg cost minus penalty per step:  10.11
# Avg quality of service:  1.94
# Avg no of virtual machines:  8.32

# %%
SCENARIO = "Environment/Scenarios/test_scenario_5_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 3.249100403714458, 'Current cost': 595, 'Queue': [5, 4, 4, 4, 4, 4, 4, 4, 4, 4], 'Timer': 3.077775001525879, 'VM type I': 10, 'VM type II': 7, 'VM type III': 2}
# Cumulative reward at the end of the test:  -625.0
# Avg cost minus penalty per step:  9.12
# Avg quality of service:  2.22
# Avg no of virtual machines:  19.07

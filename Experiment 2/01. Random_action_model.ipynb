# %% [markdown]
# # Random action agent

# %%
import pprint
from Environment.simulator import *
from Environment.my_utils import *
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv

import warnings
warnings.filterwarnings("ignore")

# %%
SLA = 50
VM_TYPE1 = 7
VM_TYPE2 = 3
VM_TYPE3 = 1
PENALTY = 10000
STEPS = 50
ALPHA = 0.75
BETA = 0.25

# %% [markdown]
# Make own copy of the scenarios

# %%
copy_scenario('test_scenario_1', 'random')
copy_scenario('test_scenario_2', 'random')
copy_scenario('test_scenario_3', 'random')
copy_scenario('test_scenario_4', 'random')
copy_scenario('test_scenario_5', 'random')

# %% [markdown]
# Test performce on random actions

# %%
SCENARIO = "Environment/Scenarios/test_scenario_1_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 24.91171454693544, 'Current cost': 660, 'Request': 30.0, 'Timer': 1.2042527198791504, 'VM type I': 8, 'VM type II': 10, 'VM type III': 2}
# Cumulative reward at the end of the test:  -24.5
# Avg cost minus penalty per step:  16.1
# Avg quality of service:  45.65
# Avg no of virtual machines:  14.62

# %%
SCENARIO = "Environment/Scenarios/test_scenario_2_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 45.760099889923936, 'Current cost': 155, 'Request': 170.0, 'Timer': 3.71502685546875, 'VM type I': 4, 'VM type II': 0, 'VM type III': 1}
# Cumulative reward at the end of the test:  8.5
# Avg cost minus penalty per step:  6.25
# Avg quality of service:  57.04
# Avg no of virtual machines:  7.38

# %%
SCENARIO = "Environment/Scenarios/test_scenario_3_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 21.16677823754681, 'Current cost': 375, 'Request': 20.0, 'Timer': 0.9448769092559814, 'VM type I': 6, 'VM type II': 3, 'VM type III': 2}
# Cumulative reward at the end of the test:  -11.5
# Avg cost minus penalty per step:  10.97
# Avg quality of service:  44.89
# Avg no of virtual machines:  10.94

# %%
SCENARIO = "Environment/Scenarios/test_scenario_4_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 15.234024547375418, 'Current cost': 350, 'Request': 20.0, 'Timer': 1.3128507137298584, 'VM type I': 5, 'VM type II': 5, 'VM type III': 1}
# Cumulative reward at the end of the test:  0.5
# Avg cost minus penalty per step:  8.28
# Avg quality of service:  51.84
# Avg no of virtual machines:  14.06

# %%
SCENARIO = "Environment/Scenarios/test_scenario_5_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 50.43587105740578, 'Current cost': 190, 'Request': 170.0, 'Timer': 3.370616912841797, 'VM type I': 6, 'VM type II': 2, 'VM type III': 0}
# Cumulative reward at the end of the test:  -18.5
# Avg cost minus penalty per step:  12.7
# Avg quality of service:  49.82
# Avg no of virtual machines:  11.1

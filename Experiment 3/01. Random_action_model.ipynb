# %% [markdown]
# # Random action agent

# %%
import pprint
from Environment.simulator import *
from Environment.my_utils import *
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv

import warnings
warnings.filterwarnings("ignore")

# %%
SLA = 50
VM_TYPE1 = 7
VM_TYPE2 = 3
VM_TYPE3 = 1
PENALTY = 10000
STEPS = 50
ALPHA = 0.25
BETA = 0.75

# %% [markdown]
# Make own copy of the scenarios

# %%
copy_scenario('test_scenario_1', 'random')
copy_scenario('test_scenario_2', 'random')
copy_scenario('test_scenario_3', 'random')
copy_scenario('test_scenario_4', 'random')
copy_scenario('test_scenario_5', 'random')

# %% [markdown]
# Test performce on random actions

# %%
SCENARIO = "Environment/Scenarios/test_scenario_1_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 23.664180308661454, 'Current cost': 355, 'Request': 30.0, 'Timer': 1.2677388191223145, 'VM type I': 3, 'VM type II': 2, 'VM type III': 3}
# Cumulative reward at the end of the test:  -47
# Avg cost minus penalty per step:  22.74
# Avg quality of service:  31.17
# Avg no of virtual machines:  8.5

# %%
SCENARIO = "Environment/Scenarios/test_scenario_2_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 46.47047525583206, 'Current cost': 160, 'Request': 170.0, 'Timer': 3.6582367420196533, 'VM type I': 8, 'VM type II': 0, 'VM type III': 0}
# Cumulative reward at the end of the test:  -19.5
# Avg cost minus penalty per step:  14.07
# Avg quality of service:  48.11
# Avg no of virtual machines:  10.42

# %%
SCENARIO = "Environment/Scenarios/test_scenario_3_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 16.852597669375115, 'Current cost': 515, 'Request': 20.0, 'Timer': 1.186760663986206, 'VM type I': 4, 'VM type II': 6, 'VM type III': 3}
# Cumulative reward at the end of the test:  -47
# Avg cost minus penalty per step:  22.75
# Avg quality of service:  34.8
# Avg no of virtual machines:  8.28

# %%
SCENARIO = "Environment/Scenarios/test_scenario_4_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 16.908067534650662, 'Current cost': 630, 'Request': 20.0, 'Timer': 1.1828672885894775, 'VM type I': 8, 'VM type II': 7, 'VM type III': 3}
# Cumulative reward at the end of the test:  -11.5
# Avg cost minus penalty per step:  11.08
# Avg quality of service:  46.11
# Avg no of virtual machines:  15.1

# %%
SCENARIO = "Environment/Scenarios/test_scenario_5_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 76.55048972959231, 'Current cost': 480, 'Request': 170.0, 'Timer': 2.2207565307617188, 'VM type I': 11, 'VM type II': 1, 'VM type III': 3}
# Cumulative reward at the end of the test:  2.0
# Avg cost minus penalty per step:  6.43
# Avg quality of service:  58.21
# Avg no of virtual machines:  12.64

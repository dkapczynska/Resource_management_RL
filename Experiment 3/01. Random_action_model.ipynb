# %% [markdown]
# # Random action agent

# %%
import pprint
from Environment.simulator import *
from Environment.my_utils import *
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv

import warnings
warnings.filterwarnings("ignore")

# %%
SLA = 2.5
VM_TYPE1 = 7
VM_TYPE2 = 3
VM_TYPE3 = 1
PENALTY = 10000
STEPS = 100
ALPHA = 0.25
BETA = 0.75

# %% [markdown]
# Make own copy of the scenarios

# %%
copy_scenario('test_scenario_1', 'random')
copy_scenario('test_scenario_2', 'random')
copy_scenario('test_scenario_3', 'random')
copy_scenario('test_scenario_4', 'random')
copy_scenario('test_scenario_5', 'random')

# %% [markdown]
# Test performce on random actions

# %%
SCENARIO = "Environment/Scenarios/test_scenario_1_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 0.9955439700422323, 'Current cost': 155, 'Queue': [20, 20, 19, 19, 19, 19, 19, 19, 19, 19], 'Timer': 10.044759750366211, 'VM type I': 6, 'VM type II': 1, 'VM type III': 0}
# Cumulative reward at the end of the test:  10.0
# Avg cost minus penalty per step:  3.52
# Avg quality of service:  2.79
# Avg no of virtual machines:  12.19

# %%
SCENARIO = "Environment/Scenarios/test_scenario_2_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 3.0042295397358276, 'Current cost': 510, 'Queue': [5, 6, 6, 6, 6, 6, 6, 6, 6, 6], 'Timer': 3.3286404609680176, 'VM type I': 4, 'VM type II': 8, 'VM type III': 2}
# Cumulative reward at the end of the test:  -620.0
# Avg cost minus penalty per step:  8.22
# Avg quality of service:  2.18
# Avg no of virtual machines:  11.84

# %%
SCENARIO = "Environment/Scenarios/test_scenario_3_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 2.181133491503452, 'Current cost': 450, 'Queue': [15, 14, 14, 14, 14, 14, 14, 14, 14, 14], 'Timer': 4.584772109985352, 'VM type I': 3, 'VM type II': 9, 'VM type III': 1}
# Cumulative reward at the end of the test:  20.0
# Avg cost minus penalty per step:  3.71
# Avg quality of service:  2.73
# Avg no of virtual machines:  13.84

# %%
SCENARIO = "Environment/Scenarios/test_scenario_4_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 2.166724998004681, 'Current cost': 550, 'Queue': [16, 17, 17, 17, 17, 17, 17, 17, 17, 17], 'Timer': 4.615260362625122, 'VM type I': 13, 'VM type II': 4, 'VM type III': 2}
# Cumulative reward at the end of the test:  -640.0
# Avg cost minus penalty per step:  8.54
# Avg quality of service:  2.31
# Avg no of virtual machines:  17.94

# %%
SCENARIO = "Environment/Scenarios/test_scenario_5_random.txt"
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, 'False')
# Out:
# info {'Quality of Service': 3.209620879725918, 'Current cost': 330, 'Queue': [5, 4, 4, 4, 4, 4, 4, 4, 4, 4], 'Timer': 3.1156327724456787, 'VM type I': 9, 'VM type II': 0, 'VM type III': 2}
# Cumulative reward at the end of the test:  -380.0
# Avg cost minus penalty per step:  6.81
# Avg quality of service:  2.37
# Avg no of virtual machines:  11.61

# %% [markdown]
# # Adventage Actor-Critic Algorithm (A2C)
# Policy-based method, based on 2 neural networks - one to model "Actor" (policy network) and second one to model "Critic" (value network). As policy-based methods are based on the probabilities, the policy network can also handle continious action spaces, which is not a case for deep Q-learnig, where every node represents one action. Policy networks can output the parameters of any distribuiotion.  Idea behind this method: Instead of coming up with loss directly, let's find its gradient -> "Policy Gradient". It also uses batch version of training.
#
# To calculate expected value we can use sampling (like in Monte Carlo), however this method performas multiple rollouts, then take the average. Now, the most imporant part - the strategy is based on Global Network and Worker networks, wchich are responsible for doing the rollouts. Every n steps, each owrker send its gradients back to master (Global Network) and then master updates its weights. So it results in the fact that master network has always most updated version the of policy.
#
# ![image.png](attachment:image.png)
#
#
# A2C in original version used to take n (in original OpenAI setting: n=5) enviroments and runs each of them in paraller. Each of them returns (s, a, r, s') and this data in used to update master network. The paraller processes are done synchronously (main difference in respect to A3C).
#
# Advetages:
# - no need to implement epsilon-greedy algorithm like in Q-learning
# - more control over randomness
# - regularization through entropy
#
# Paper: https://arxiv.org/abs/1602.01783
#
# Implementation: - using stable baseline 3 that are based on OpenAI Gym Baselines algorithms (https://github.com/DLR-RM/stable-baselines3/tree/master/stable_baselines3/a2c)

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116

# %%
import os
import pprint
import random
import warnings
import numpy as np

from gym import Env
from Environment.simulator import *
from Environment.my_utils import *
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy

import gym
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
model_path = os.path.join('Training', 'Saved Models', 'best_model_A2C')

warnings.filterwarnings("ignore")

# %% [markdown]
# Prepare the enviroment

# %%
# SIM PARAMETERS
SLA = 2.5
VM_TYPE1 = 7
VM_TYPE2 = 3
VM_TYPE3 = 1
PENALTY = 10000
STEPS = 100
ALPHA = 0.5
BETA = 0.5
SCENARIO = "Environment/Scenarios/train_A2C.txt"

env = Sim(sla = SLA,
          vm_1 = VM_TYPE1,
          vm_2 = VM_TYPE2,
          vm_3 = VM_TYPE3,
          penalty = PENALTY,
          steps = STEPS,
          scenario = SCENARIO,
          alpha = ALPHA,
          beta = BETA)

env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# %% [markdown]
# Create private copy of the scenarios

# %%
copy_scenario('train', 'A2C', 210)
copy_scenario('test_scenario_1', 'A2C')
copy_scenario('test_scenario_2', 'A2C')
copy_scenario('test_scenario_3', 'A2C')
copy_scenario('test_scenario_4', 'A2C')
copy_scenario('test_scenario_5', 'A2C')

# %% [markdown]
# Train the model

# %%
model = A2C('MlpPolicy', env, verbose = 1, learning_rate=1e-3, gamma=0.99)
model.learn(total_timesteps=10000, reset_num_timesteps = False)
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 100      |
# |    time_elapsed       | 1366     |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | -32.5    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 99       |
# |    policy_loss        | 0.158    |
# |    value_loss         | 0.111    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 200      |
# |    time_elapsed       | 2723     |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.832   |
# |    explained_variance | -0.129   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0077   |
# |    value_loss         | 0.000108 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 300      |
# |    time_elapsed       | 4082     |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.722   |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 299      |
# |    policy_loss        | -0.00896 |
# |    value_loss         | 1.9e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 0         |
# |    iterations         | 400       |
# |    time_elapsed       | 5437      |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -0.358    |
# |    explained_variance | -0.101    |
# |    learning_rate      | 0.001     |
# |    n_updates          | 399       |
# |    policy_loss        | -7.01e-05 |
# |    value_loss         | 5.94e-07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 500      |
# |    time_elapsed       | 6804     |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.238   |
# |    explained_variance | 0.008    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 499      |
# |    policy_loss        | 5.13e-05 |
# |    value_loss         | 1.04e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 600      |
# |    time_elapsed       | 8166     |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.0767  |
# |    explained_variance | 0.000861 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 599      |
# |    policy_loss        | 6.11e-05 |
# |    value_loss         | 2.66e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 700      |
# |    time_elapsed       | 9552     |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.0394  |
# |    explained_variance | 0.187    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 699      |
# |    policy_loss        | 4.67e-06 |
# |    value_loss         | 8.46e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 0         |
# |    iterations         | 800       |
# |    time_elapsed       | 10908     |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.046    |
# |    explained_variance | -3.29     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 799       |
# |    policy_loss        | -5.27e-07 |
# |    value_loss         | 6.7e-09   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 0         |
# |    iterations         | 900       |
# |    time_elapsed       | 12268     |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.0404   |
# |    explained_variance | -1.03e+03 |
# |    learning_rate      | 0.001     |
# |    n_updates          | 899       |
# |    policy_loss        | -0.0563   |
# |    value_loss         | 0.000587  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1000     |
# |    time_elapsed       | 13650    |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.0101  |
# |    explained_variance | 0.786    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 1.29e-07 |
# |    value_loss         | 1.57e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1100     |
# |    time_elapsed       | 15014    |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.00979 |
# |    explained_variance | -0.352   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1099     |
# |    policy_loss        | 1.51e-07 |
# |    value_loss         | 2.27e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1200     |
# |    time_elapsed       | 16364    |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.00964 |
# |    explained_variance | 0.389    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1199     |
# |    policy_loss        | 2.81e-07 |
# |    value_loss         | 7.91e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1300     |
# |    time_elapsed       | 17741    |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.00313 |
# |    explained_variance | 0.0483   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1299     |
# |    policy_loss        | 1.09e-07 |
# |    value_loss         | 1.51e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1400     |
# |    time_elapsed       | 19101    |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.00669 |
# |    explained_variance | -0.181   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1399     |
# |    policy_loss        | 1.68e-07 |
# |    value_loss         | 6.6e-08  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1500     |
# |    time_elapsed       | 20474    |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.00666 |
# |    explained_variance | 0.171    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1499     |
# |    policy_loss        | 3e-07    |
# |    value_loss         | 2.11e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1600     |
# |    time_elapsed       | 21831    |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.00659 |
# |    explained_variance | -0.0948  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1599     |
# |    policy_loss        | 2.82e-07 |
# |    value_loss         | 1.91e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1700     |
# |    time_elapsed       | 23207    |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.00657 |
# |    explained_variance | 0.084    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1699     |
# |    policy_loss        | 3.99e-07 |
# |    value_loss         | 3.82e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1800     |
# |    time_elapsed       | 24552    |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.00645 |
# |    explained_variance | -0.0718  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1799     |
# |    policy_loss        | 3.35e-07 |
# |    value_loss         | 2.81e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 1900     |
# |    time_elapsed       | 25899    |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.00645 |
# |    explained_variance | 0.0519   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1899     |
# |    policy_loss        | 4.63e-07 |
# |    value_loss         | 5.35e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 0        |
# |    iterations         | 2000     |
# |    time_elapsed       | 27262    |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.00617 |
# |    explained_variance | -0.0588  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 3.6e-07  |
# |    value_loss         | 3.59e-07 |
# ------------------------------------

# %%
model.save(model_path)

# %%
del model

# %%
model = A2C.load(model_path, env=env)

# %% [markdown]
# Evaluate the policy

# %%
# evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %% [markdown]
# Test the model

# %%
SCENARIO = 'Environment/Scenarios/test_scenario_1_A2C.txt'
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, model)
# Out:
# info {'Quality of Service': 2.649945128504178, 'Current cost': 80, 'Queue': [7, 7, 7, 7, 7, 7, 7, 7, 7, 7], 'Timer': 3.77366304397583, 'VM type I': 4, 'VM type II': 0, 'VM type III': 0}
# Cumulative reward at the end of the test:  235.0
# Avg cost minus penalty per step:  2.0
# Avg quality of service:  3.7
# Avg no of virtual machines:  8.23

# %%
SCENARIO = 'Environment/Scenarios/test_scenario_2_A2C.txt'
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, model)
# Out:
# info {'Quality of Service': 3.7696550027039066, 'Current cost': 455, 'Queue': [5, 6, 6, 6, 6, 6, 6, 6, 6, 6], 'Timer': 2.6527626514434814, 'VM type I': 10, 'VM type II': 3, 'VM type III': 2}
# Cumulative reward at the end of the test:  -395.0
# Avg cost minus penalty per step:  6.53
# Avg quality of service:  2.77
# Avg no of virtual machines:  14.32

# %%
SCENARIO = 'Environment/Scenarios/test_scenario_3_A2C.txt'
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, model)
# Out:
# info {'Quality of Service': 2.282915331751483, 'Current cost': 265, 'Queue': [15, 14, 14, 14, 14, 14, 14, 14, 14, 14], 'Timer': 4.380363941192627, 'VM type I': 1, 'VM type II': 7, 'VM type III': 0}
# Cumulative reward at the end of the test:  200.0
# Avg cost minus penalty per step:  1.98
# Avg quality of service:  3.54
# Avg no of virtual machines:  13.49

# %%
SCENARIO = 'Environment/Scenarios/test_scenario_4_A2C.txt'
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, model)
# Out:
# info {'Quality of Service': 2.444897753381091, 'Current cost': 315, 'Queue': [16, 17, 17, 17, 17, 17, 17, 17, 17, 17], 'Timer': 4.090150594711304, 'VM type I': 12, 'VM type II': 0, 'VM type III': 1}
# Cumulative reward at the end of the test:  -60.0
# Avg cost minus penalty per step:  4.44
# Avg quality of service:  2.66
# Avg no of virtual machines:  12.47

# %%
SCENARIO = 'Environment/Scenarios/test_scenario_5_A2C.txt'
test_model(SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA, model)
# Out:
# info {'Quality of Service': 3.757397904770931, 'Current cost': 545, 'Queue': [5, 4, 4, 4, 4, 4, 4, 4, 4, 4], 'Timer': 2.6614162921905518, 'VM type I': 2, 'VM type II': 8, 'VM type III': 3}
# Cumulative reward at the end of the test:  -120.0
# Avg cost minus penalty per step:  5.05
# Avg quality of service:  2.88
# Avg no of virtual machines:  13.62

# %% [markdown]
# # Adventage Actor-Critic Algorithm (A2C)
# Policy-based method, based on 2 neural networks - one to model "Actor" (policy network) and second one to model "Critic" (value network). As policy-based methods are based on the probabilities, the policy network can also handle continious action spaces, which is not a case for deep Q-learnig, where every node represents one action. Policy networks can output the parameters of any distribuiotion.  Idea behind this method: Instead of coming up with loss directly, let's find its gradient -> "Policy Gradient". It also uses batch version of training.
#
# To calculate expected value we can use sampling (like in Monte Carlo), however this method performas multiple rollouts, then take the average. Now, the most imporant part - the strategy is based on Global Network and Worker networks, wchich are responsible for doing the rollouts. Every n steps, each owrker send its gradients back to master (Global Network) and then master updates its weights. So it results in the fact that master network has always most updated version the of policy.
#
# ![image.png](attachment:image.png)
#
#
# A2C in original version used to take n (in original OpenAI setting: n=5) enviroments and runs each of them in paraller. Each of them returns (s, a, r, s') and this data in used to update master network. The paraller processes are done synchronously (main difference in respect to A3C).
#
# Advetages:
# - no need to implement epsilon-greedy algorithm like in Q-learning
# - more control over randomness
# - regularization through entropy
#
# Paper: https://arxiv.org/abs/1602.01783
#
# Implementation: - using stable baseline 3 that are based on OpenAI Gym Baselines algorithms (https://github.com/DLR-RM/stable-baselines3/tree/master/stable_baselines3/a2c)

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116

# %%
import os
import pprint
import random
import warnings
import numpy as np

from gym import Env
from Environment.simulator import *
from Environment.my_utils import *
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy

import gym
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3 import A2C
from stable_baselines3.common.env_util import make_vec_env

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
model_path = os.path.join('Training', 'Saved Models', 'best_model_A2C')

warnings.filterwarnings("ignore")

# %% [markdown]
# Prepare the enviroment

# %%
# SIM PARAMETERS
SLA = 10
VM_TYPE1 = 7
VM_TYPE2 = 3
VM_TYPE3 = 1
SCENARIO = 'random'
PENALTY = 500
STEPS = 100
ALPHA = 0.5
BETA = 0.5

env = Sim(sla = SLA,
          vm_1 = VM_TYPE1,
          vm_2 = VM_TYPE2,
          vm_3 = VM_TYPE3,
          penalty = PENALTY,
          steps = STEPS,
          scenario = SCENARIO,
          alpha = ALPHA,
          beta = BETA)

env = DummyVecEnv([lambda: env])
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# %% [markdown]
# Train the model

# %%
model = A2C('MlpPolicy', env, verbose = 1, learning_rate=1e-3, gamma=0.99)
model.learn(total_timesteps=5000, reset_num_timesteps = False)
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 100      |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.758   |
# |    explained_variance | 0.262    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0582   |
# |    value_loss         | 0.0053   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 4         |
# |    iterations         | 200       |
# |    time_elapsed       | 237       |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -0.799    |
# |    explained_variance | 0.168     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 199       |
# |    policy_loss        | -0.000676 |
# |    value_loss         | 8.11e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 300      |
# |    time_elapsed       | 359      |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.556   |
# |    explained_variance | -0.00473 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 299      |
# |    policy_loss        | 0.000722 |
# |    value_loss         | 2.33e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 400      |
# |    time_elapsed       | 482      |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.357   |
# |    explained_variance | -0.00202 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 399      |
# |    policy_loss        | 0.000374 |
# |    value_loss         | 2.19e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 500      |
# |    time_elapsed       | 601      |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.187   |
# |    explained_variance | -0.0137  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 499      |
# |    policy_loss        | 0.000211 |
# |    value_loss         | 3.64e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 600      |
# |    time_elapsed       | 721      |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.0529  |
# |    explained_variance | -0.00706 |
# |    learning_rate      | 0.001    |
# |    n_updates          | 599      |
# |    policy_loss        | 4.48e-05 |
# |    value_loss         | 3.72e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 700      |
# |    time_elapsed       | 842      |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.0253  |
# |    explained_variance | -0.0122  |
# |    learning_rate      | 0.001    |
# |    n_updates          | 699      |
# |    policy_loss        | 3.77e-06 |
# |    value_loss         | 1.53e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 800      |
# |    time_elapsed       | 966      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.0298  |
# |    explained_variance | 0.718    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 799      |
# |    policy_loss        | 3.28e-07 |
# |    value_loss         | 9.1e-09  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 900      |
# |    time_elapsed       | 1088     |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.0114  |
# |    explained_variance | 0.504    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 899      |
# |    policy_loss        | 1e-07    |
# |    value_loss         | 7.88e-09 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 4        |
# |    iterations         | 1000     |
# |    time_elapsed       | 1210     |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.0103  |
# |    explained_variance | 0.347    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 2.5e-07  |
# |    value_loss         | 5.62e-08 |
# ------------------------------------

# %%
model.save(model_path)

# %%
del model

# %%
model = A2C.load(model_path, env=env)

# %% [markdown]
# Evaluate the policy

# %%
# evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %% [markdown]
# Test the model

# %%
SCENARIO = 'test_scenario_1'
test_model_SB(model, SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA)
# Out:
# info {'Quality of Service': 19.13195393155052, 'Current cost': 480, 'Semi-stochastic queue': [4, 5, 6, 7, 7, 10, 10, 11, 12, 10], 'Timer': 0.5226857662200928, 'VM type I': 15, 'VM type II': 3, 'VM type III': 1}
# Cumulative reward at the end of the test:  99
# Avg cost minus penalty per step:  0.27
# Avg quality of service:  19.47
# Avg no of virtual machines:  18.72

# %%
SCENARIO = 'test_scenario_2'
test_model_SB(model, SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, 10, SCENARIO, PENALTY, ALPHA, BETA)
# Out:
# info {'Quality of Service': 9.529520286819134, 'Current cost': 480, 'Semi-stochastic queue': [8, 10, 7, 5, 3, 4, 6, 5, 9, 10], 'Timer': 1.0493707656860352, 'VM type I': 15, 'VM type II': 3, 'VM type III': 1}
# Cumulative reward at the end of the test:  -9
# Avg cost minus penalty per step:  8.18
# Avg quality of service:  9.56
# Avg no of virtual machines:  16.2

# %%
SCENARIO = 'test_scenario_3'
test_model_SB(model, SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA)
# Out:
# info {'Quality of Service': 7.623215789709005, 'Current cost': 480, 'Semi-stochastic queue': [10, 10, 9, 8, 7, 6, 5, 6, 4, 3], 'Timer': 1.3117823600769043, 'VM type I': 15, 'VM type II': 3, 'VM type III': 1}
# Cumulative reward at the end of the test:  -99
# Avg cost minus penalty per step:  0.84
# Avg quality of service:  7.64
# Avg no of virtual machines:  18.72

# %%
# SCENARIO = ''
# test_model_SB(model, SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA)
# Out:
# info {'Quality of Service': 127.0359616355376, 'Current cost': 480, 'Semi-stochastic queue': [1, 2, 2, 2, 2, 3, 2, 1, 1, 2, 1, 3], 'Timer': 0.09446144104003906, 'VM type I': 15, 'VM type II': 3, 'VM type III': 1}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-349870d9091c> in <module>
#       1 SCENARIO = ''
# ----> 2 test_model_SB(model, SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA)
#
# /workspace/Environment/my_utils.py in test_model_SB(model, SLA, VM_TYPE1, VM_TYPE2, VM_TYPE3, STEPS, SCENARIO, PENALTY, ALPHA, BETA)
#      85
#      86     # average queue
# ---> 87     queue_df = pd.DataFrame(queues)
#      88     queue_avg = list(queue_df.mean(axis=1))
#      89     utility_function = list(np.reshape(utility_function, [STEPS,]))
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# --> 502     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     503
#     504
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     118         # figure out the index, if necessary
#     119         if index is None:
# --> 120             index = _extract_index(arrays)
#     121         else:
#     122             index = ensure_index(index)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     672             lengths = list(set(raw_lengths))
#     673             if len(lengths) > 1:
# --> 674                 raise ValueError("All arrays must be of the same length")
#     675
#     676             if have_dicts:
#
# ValueError: All arrays must be of the same length
